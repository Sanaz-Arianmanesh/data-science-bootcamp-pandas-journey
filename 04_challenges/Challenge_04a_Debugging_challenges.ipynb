# %% [markdown]
# # Python Debugging Exercises 🐞
# Welcome! In each exercise below, you'll find some buggy Python code. 🐛 Your mission is to fix the error and get the code running. We give hints to help you along the way! 😊

# %% [markdown]
# ---
# ## Exercise 1
# The code is trying to print a greeting, but there's a bug 🐛 in the `print` statement.

# %%
print "Hello, world!"
# Out:
#   File "/tmp/ipython-input-2804745302.py", line 1
#     print "Hello, world!"
#     ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?

# %%
print("Hello, world!")
# print is a function, so it must be called with parentheses.

# %% [markdown]
# ---
# ## Exercise 2
# We have a variable `message`, but I can't print it. Uh oh!

# %%
message = "Hi there!"
print(mesage)

# %%
message = "Hi there!"
print(message)
# Python is case-sensitive and spelling-sensitive

# %% [markdown]
# ---
# ## Exercise 3
# Our `print` statement is having problems again. Can you find what's wrong here?

# %%
if True:
print("Oh no!")

# %%
# Python requires an indented block after an if statement
if True:
  print("Oh no!")

# %% [markdown]
# ---
# ## Exercise 4
# If only this would work!

# %%
if 5 > 3
    print("5 is greater than 3")
# Out:
#   File "/tmp/ipython-input-996193472.py", line 1
#     if 5 > 3
#             ^
# SyntaxError: expected ':'

# %%
# This error means Python was expecting a colon :
if 5 > 3:
    print("5 is greater than 3")

# %% [markdown]
# ---
# ## Exercise 5
# Why won't this code print out my age?

# %%
age = 30
print("I am " + age + " years old")

# %%
# In Python, strings (str) and numbers (int) are different data types, and they cannot be combined directly.
age = 25
print("I am " + str(age) + " years old")

# %% [markdown]
# ---
# ## Exercise 6
# I'd like to print out the `cherry`, why won't the code let me?

# %%
fruits = ["apple", "banana", "cherry"]
print(fruits[3])

# %%
# It means we are useing an index outside the valid range of a list
fruits = ["apple", "banana", "cherry"]
print(fruits[2])

# %% [markdown]
# ---
# ## Exercise 7
# Why can't `int()` turn `ten` into an integer? Can it convert stings to integers?

# %%
number = int("ten")

# %%
# int() only works with numeric strings
number = int("10")

# %% [markdown]
# ---
# ## Exercise 8
# What's wrong with the loop?

# %%
for i in range(3)
    print(i)
# Out:
#   File "/tmp/ipython-input-859882524.py", line 1
#     for i in range(3)
#                      ^
# SyntaxError: expected ':'

# %%
# Statements must end with a colon.
for i in range(3):
    print(i)

# %% [markdown]
# ---
# ## Exercise 9
# A string isn't recognised? What's up?

# %%
print("Hello)

# %%
# This error means a string was started but not closed.
print("Hello")

# %% [markdown]
# ---
# ## Exercise 10
# Is it possible to multiply a string? If so, how?

# %%
sound = "ha"
print(sound * 2.5)

# %%
# Multiplying by a float is invalid
print(sound * 2)

# %% [markdown]
# ---
# ## Exercise 11
# What's wrong with this loop?

# %%
for i in range(5.5):
    print(i)

# %%
# range() does not accept floats.
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# ---
# ## Exercise 12
# Why can't the list be printed?

# %%
items = [1, 2, 3]
print(item)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2175550346.py in <cell line: 0>()
#       1 items = [1, 2, 3]
# ----> 2 print(item)
#
# NameError: name 'item' is not defined

# %%
# Python is case-sensitive and name-sensitive
print(items)

# %% [markdown]
# ---
# ## Exercise 13
# Why won't this code print out the 5 letter of `hello`?

# %%
s = "hello"
print(s[5])

# %%
# Strings are 0-indexed in Python. The string "hello" has length 5
print(s[4])      # 'o'

# %% [markdown]
# ---
# ## Exercise 14
# Why can't `4` be added to the list? Can you add `4` to the list in `print()`?

# %%
nums = [1, 2, 3]
print(nums + 4)

# %%
# Concatenating a list and an integer is not valid.
nums.append(4)
print(nums)

# %% [markdown]
# ---
# ## Exercise 15
# Nothing plus 5 is surely 5. Is it possible to save this code?

# %%
value = None
print(value + 5)

# %%
# None cannot be used in arithmetic operations.
value = 0
print(value + 5)
